# %%
from pathlib import Path
import joblib
import lightgbm as lgb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
FEATURE_COLUMNS = [
    "lead_hours",
    "lead_norm",

    "v_obs",
    "n_obs",
    "bz_obs",
    "bt_obs",
    "kp",

    "v_persist_1h",
    "v_persist_6h",
    "v_persist_24h",
    "v_persist_27d",

    "delta_v_1h_6h",
    "delta_v_1h_24h",
    "delta_v_24h_27d",

    "abs_bz",
    "southward_bz",

    "issue_sin_27d",
    "issue_cos_27d",
    "valid_sin_27d",
    "valid_cos_27d",
]


BASELINES = {
    "persist_1h": "v_persist_1h",
    "persist_6h": "v_persist_6h",
    "persist_24h": "v_persist_24h",
    "persist_27d": "v_persist_27d",
}


def load_dataset(path: Path) -> pd.DataFrame:
    df = pd.read_csv(path)

    df["issue_time"] = pd.to_datetime(df["issue_time"], utc=True)
    df["valid_time"] = pd.to_datetime(df["valid_time"], utc=True)

    needed = ["issue_time", "valid_time", "target_v", *FEATURE_COLUMNS]
    missing = [c for c in needed if c not in df.columns]
    if missing:
        raise ValueError(f"Missing columns: {missing}")

    df = df.dropna(subset=["target_v", *FEATURE_COLUMNS])
    df = df.sort_values(["issue_time", "lead_hours"])

    return df

# %%
def time_split(df: pd.DataFrame, train_ratio: float) -> tuple[pd.DataFrame, pd.DataFrame]:
    issue_times = np.array(sorted(df["issue_time"].unique()))
    split_idx = int(len(issue_times) * train_ratio)

    train_until = issue_times[split_idx]

    train = df[df["issue_time"] < train_until].copy()
    valid = df[df["issue_time"] >= train_until].copy()

    return train, valid


def metrics(y_true: np.ndarray, y_pred: np.ndarray) -> dict[str, float]:
    return {
        "mae": mean_absolute_error(y_true, y_pred),
        "rmse": root_mean_squared_error(y_true, y_pred),
        "bias": float(np.mean(y_pred - y_true)),
    }


def evaluate_by_lead(df: pd.DataFrame, pred_col: str) -> pd.DataFrame:
    rows = []

    for lead, g in df.groupby("lead_hours"):
        m = metrics(g["target_v"].values, g[pred_col].values)
        rows.append({
            "model": pred_col,
            "lead_hours": lead,
            **m,
            "n": len(g),
        })

    return pd.DataFrame(rows)

def add_blended_baseline(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()

    # Simple hand-made blend:
    # short horizon: recent persistence dominates
    # long horizon: 24h and 27d recurrence get more weight
    lead = df["lead_hours"].clip(1, 96)

    w_recent = np.maximum(0.15, 1.0 - lead / 96.0)
    w_24h = 0.25
    w_27d = 1.0 - w_recent - w_24h
    w_27d = np.maximum(0.0, w_27d)

    total = w_recent + w_24h + w_27d

    w_recent = w_recent / total
    w_24h = w_24h / total
    w_27d = w_27d / total

    df["baseline_blend"] = (
        w_recent * df["v_persist_1h"]
        + w_24h * df["v_persist_24h"]
        + w_27d * df["v_persist_27d"]
    )

    return df

# %%
df = load_dataset(Path("../../data/historical/omni_processed.csv"))
df = add_blended_baseline(df)
df.head()
# Out:
#                  issue_time                valid_time  lead_hours  lead_norm  \
# 0 2020-01-28 00:00:00+00:00 2020-01-28 01:00:00+00:00           1   0.010417
# 1 2020-01-28 00:00:00+00:00 2020-01-28 02:00:00+00:00           2   0.020833
# 2 2020-01-28 00:00:00+00:00 2020-01-28 03:00:00+00:00           3   0.031250
# 3 2020-01-28 00:00:00+00:00 2020-01-28 04:00:00+00:00           4   0.041667
# 4 2020-01-28 00:00:00+00:00 2020-01-28 05:00:00+00:00           5   0.052083
#
#    target_v  v_obs  n_obs  bz_obs   bt_obs    kp  ...  issue_sin_27d  \
# 0     321.0  309.0    5.0     0.4  3.54542  10.0  ...      -0.877916
# 1     319.0  309.0    5.0     0.4  3.54542  10.0  ...      -0.877916
# 2     320.0  309.0    5.0     0.4  3.54542  10.0  ...      -0.877916
# 3     320.0  309.0    5.0     0.4  3.54542  10.0  ...      -0.877916
# 4     322.0  309.0    5.0     0.4  3.54542  10.0  ...      -0.877916
#
#    issue_cos_27d  valid_sin_27d  valid_cos_27d  target_high_speed_450  \
# 0      -0.478814      -0.217779      -0.975998                      0
# 1      -0.478814      -0.227137      -0.973863                      0
# 2      -0.478814      -0.236474      -0.971638                      0
# 3      -0.478814      -0.245789      -0.969323                      0
# 4      -0.478814      -0.255082      -0.966920                      0
#
#    target_high_speed_500  target_high_speed_600  target_high_speed_700  \
# 0                      0                      0                      0
# 1                      0                      0                      0
# 2                      0                      0                      0
# 3                      0                      0                      0
# 4                      0                      0                      0
#
#    target_high_speed_800  baseline_blend
# 0                      0      313.991597
# 1                      0      313.983051
# 2                      0      313.974359
# 3                      0      313.965517
# 4                      0      313.956522
#
# [5 rows x 29 columns]

# %%
train, valid = time_split(df, 0.8)

# %%
from sklearn.metrics import mean_absolute_error, root_mean_squared_error

results = []

for name, col in BASELINES.items():
    valid[f"pred_{name}"] = valid[col]
    m = metrics(valid["target_v"].values, valid[f"pred_{name}"].values)
    print(f"{name}: MAE={m['mae']:.2f}, RMSE={m['rmse']:.2f}, Bias={m['bias']:.2f}")
    results.append(evaluate_by_lead(valid, f"pred_{name}"))
# Out:
# persist_1h: MAE=70.88, RMSE=95.88, Bias=-1.69
# persist_6h: MAE=74.84, RMSE=99.58, Bias=-1.91
# persist_24h: MAE=85.37, RMSE=110.31, Bias=-2.37
# persist_27d: MAE=98.52, RMSE=124.33, Bias=5.02

# %%
valid["pred_blend"] = valid["baseline_blend"]
m = metrics(valid["target_v"].values, valid["pred_blend"].values)
print(f"blend: MAE={m['mae']:.2f}, RMSE={m['rmse']:.2f}, Bias={m['bias']:.2f}")
results.append(evaluate_by_lead(valid, "pred_blend"))
# Out:
# blend: MAE=69.04, RMSE=91.96, Bias=-0.05

# %%
def train_lgbm(train: pd.DataFrame) -> lgb.LGBMRegressor:
    model = lgb.LGBMRegressor(
        objective="regression",
        n_estimators=1200,
        learning_rate=0.03,
        num_leaves=63,
        max_depth=-1,
        min_child_samples=80,
        subsample=0.85,
        colsample_bytree=0.85,
        reg_alpha=0.1,
        reg_lambda=1.0,
        random_state=42,
        n_jobs=-1,
    )

    model.fit(
        train[FEATURE_COLUMNS],
        train["target_v"],
        eval_set=[(train[FEATURE_COLUMNS], train["target_v"])],
        eval_metric="l1",
    )

    return model
    
lgbm_model = train_lgbm(train)

valid["pred_lgbm"] = lgbm_model.predict(valid[FEATURE_COLUMNS])
m = metrics(valid["target_v"].values, valid["pred_lgbm"].values)
print(f"lgbm: MAE={m['mae']:.2f}, RMSE={m['rmse']:.2f}, Bias={m['bias']:.2f}")
results.append(evaluate_by_lead(valid, "pred_lgbm"))
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.021194 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4346
# [LightGBM] [Info] Number of data points in the train set: 2454336, number of used features: 20
# [LightGBM] [Info] Start training from score 411.231879
# lgbm: MAE=75.01, RMSE=92.24, Bias=27.50

# %%
for name, value in zip(FEATURE_COLUMNS, lgbm_model.feature_importances_):
    print(f"{name:25s} {value}")
# Out:
# lead_hours                3664
# lead_norm                 602
# v_obs                     2557
# n_obs                     1827
# bz_obs                    338
# bt_obs                    1370
# kp                        872
# v_persist_1h              1108
# v_persist_6h              1269
# v_persist_24h             2074
# v_persist_27d             3174
# delta_v_1h_6h             421
# delta_v_1h_24h            1144
# delta_v_24h_27d           2207
# abs_bz                    115
# southward_bz              61
# issue_sin_27d             14862
# issue_cos_27d             8057
# valid_sin_27d             14959
# valid_cos_27d             13719

# %%
MODELS = [
    "pred_persist_1h",
    "pred_persist_6h",
    "pred_persist_24h",
    "pred_persist_27d",
    "pred_blend",
    "pred_lgbm",
]


rows = []

for lead_hour, g in valid.groupby("lead_hours"):

    y_true = g["target_v"].values

    for model in MODELS:

        y_pred = g[model].values

        rows.append({
            "lead_hours": lead_hour,
            "model": model,
            "mae": mean_absolute_error(y_true, y_pred),
            "rmse": root_mean_squared_error(
                y_true,
                y_pred
            ),
        })

metrics_by_lead = pd.DataFrame(rows)

# %%
plt.figure(figsize=(14, 7))

for model in MODELS:

    g = metrics_by_lead[
        metrics_by_lead["model"] == model
    ]

    plt.plot(
        g["lead_hours"],
        g["mae"],
        label=model,
    )

plt.xlabel("Lead Hour")
plt.ylabel("MAE")
plt.title("MAE vs Forecast Horizon")

plt.grid(True)
plt.legend()

plt.show()

# %%
plt.figure(figsize=(14, 7))

for model in MODELS:

    g = metrics_by_lead[
        metrics_by_lead["model"] == model
    ]

    plt.plot(
        g["lead_hours"],
        g["rmse"],
        label=model,
    )

plt.xlabel("Lead Hour")
plt.ylabel("RMSE")
plt.title("RMSE vs Forecast Horizon")

plt.grid(True)
plt.legend()

plt.show()

# %%
def assign_bucket(lead_hours: int) -> str:

    if 1 <= lead_hours <= 24:
        return "short_1_24"

    if 25 <= lead_hours <= 48:
        return "medium_25_48"

    return "extended_49_96"

# %%
df = df.copy()
df["lead_bucket"] = df["lead_hours"].apply(assign_bucket)

train, valid = time_split(df, 0.8)

# %%
models = {}

for bucket in df["lead_bucket"].unique():

    train_bucket = train[
        train["lead_bucket"] == bucket
    ]

    model = train_lgbm(train_bucket)

    models[bucket] = model
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005260 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4203
# [LightGBM] [Info] Number of data points in the train set: 622327, number of used features: 20
# [LightGBM] [Info] Start training from score 411.169225
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004680 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4203
# [LightGBM] [Info] Number of data points in the train set: 612556, number of used features: 20
# [LightGBM] [Info] Start training from score 411.214359
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009798 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4244
# [LightGBM] [Info] Number of data points in the train set: 1219453, number of used features: 20
# [LightGBM] [Info] Start training from score 411.272655

# %%
valid["pred_persist_1h"] = valid["v_persist_1h"]
valid["pred_persist_6h"] = valid["v_persist_6h"]
valid["pred_persist_24h"] = valid["v_persist_24h"]
valid["pred_persist_27d"] = valid["v_persist_27d"]
valid["pred_blend"] = valid["baseline_blend"]

valid["pred_global_lgbm"] = lgbm_model.predict(valid[FEATURE_COLUMNS])

valid["pred_bucketed_lgbm"] = np.nan

for bucket, model in models.items():
    mask = valid["lead_bucket"] == bucket
    valid.loc[mask, "pred_bucketed_lgbm"] = model.predict(
        valid.loc[mask, FEATURE_COLUMNS]
    )

# %%
MODELS = [
    "pred_persist_1h",
    "pred_persist_6h",
    "pred_persist_24h",
    "pred_persist_27d",
    "pred_blend",
    "pred_global_lgbm",
    "pred_bucketed_lgbm",
]


rows = []

for lead_hour, g in valid.groupby("lead_hours"):
    y_true = g["target_v"].values

    for model_name in MODELS:
        y_pred = g[model_name].values

        rows.append({
            "lead_hours": lead_hour,
            "model": model_name,
            "mae": mean_absolute_error(y_true, y_pred),
            "rmse": root_mean_squared_error(y_true, y_pred),
            "bias": float(np.mean(y_pred - y_true)),
            "n": len(g),
        })


metrics_by_lead = pd.DataFrame(rows)
metrics_by_lead.head(7)
# Out:
#    lead_hours               model        mae        rmse       bias     n
# 0           1     pred_persist_1h  13.480183   20.608953  -0.087805  6560
# 1           1     pred_persist_6h  26.419817   39.184733  -0.260366  6560
# 2           1    pred_persist_24h  57.263872   77.339632  -0.937957  6560
# 3           1    pred_persist_27d  88.670579  114.542235   6.473628  6560
# 4           1          pred_blend  18.112144   25.648035  -0.259264  6560
# 5           1    pred_global_lgbm  42.757034   53.401384  23.020726  6560
# 6           1  pred_bucketed_lgbm  18.249869   23.561410   5.956977  6560

# %%
plt.figure(figsize=(14, 7))

for model_name in MODELS:
    g = metrics_by_lead[metrics_by_lead["model"] == model_name]

    plt.plot(
        g["lead_hours"],
        g["mae"],
        label=model_name,
        linewidth=2,
    )

plt.xlabel("Lead hour")
plt.ylabel("MAE, km/s")
plt.title("MAE vs Forecast Horizon")
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14, 7))

for model_name in MODELS:
    g = metrics_by_lead[metrics_by_lead["model"] == model_name]

    plt.plot(
        g["lead_hours"],
        g["rmse"],
        label=model_name,
        linewidth=2,
    )

plt.xlabel("Lead hour")
plt.ylabel("RMSE, km/s")
plt.title("RMSE vs Forecast Horizon")
plt.grid(True)
plt.legend()
plt.show()

# %%
baseline_name = "pred_blend"

base = metrics_by_lead[
    metrics_by_lead["model"] == baseline_name
][["lead_hours", "mae"]].rename(columns={"mae": "baseline_mae"})

improvement = metrics_by_lead.merge(base, on="lead_hours")
improvement["mae_improvement_pct"] = (
    (improvement["baseline_mae"] - improvement["mae"])
    / improvement["baseline_mae"]
    * 100.0
)

plot_models = [
    "pred_global_lgbm",
    "pred_bucketed_lgbm",
]

plt.figure(figsize=(14, 7))

for model_name in plot_models:
    g = improvement[improvement["model"] == model_name]

    plt.plot(
        g["lead_hours"],
        g["mae_improvement_pct"],
        label=model_name,
        linewidth=2,
    )

plt.axhline(0, linestyle="--", linewidth=1)

plt.xlabel("Lead hour")
plt.ylabel("MAE improvement over blend, %")
plt.title("Relative MAE Improvement vs Blend Baseline")
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14, 7))

for model_name in [
    "pred_blend",
    "pred_global_lgbm",
    "pred_bucketed_lgbm",
]:
    g = metrics_by_lead[metrics_by_lead["model"] == model_name]

    plt.plot(
        g["lead_hours"],
        g["bias"],
        label=model_name,
        linewidth=2,
    )

plt.axhline(0, linestyle="--", linewidth=1)

plt.xlabel("Lead hour")
plt.ylabel("Bias, km/s")
plt.title("Forecast Bias vs Horizon")
plt.grid(True)
plt.legend()
plt.show()

# %%
def plot_feature_importance(model, feature_columns, title, top_n=15):
    importance = pd.DataFrame({
        "feature": feature_columns,
        "importance": model.feature_importances_,
    }).sort_values("importance", ascending=False).head(top_n)

    plt.figure(figsize=(10, 7))
    plt.barh(
        importance["feature"][::-1],
        importance["importance"][::-1],
    )
    plt.xlabel("Importance")
    plt.title(title)
    plt.grid(True, axis="x")
    plt.show()


plot_feature_importance(
    lgbm_model,
    FEATURE_COLUMNS,
    "Global LightGBM Feature Importance",
)

# %%
for bucket, model in models.items():
    plot_feature_importance(
        model,
        FEATURE_COLUMNS,
        f"Feature Importance — {bucket}",
    )

# %%
for model_name in [
    "pred_blend",
    "pred_global_lgbm",
    "pred_bucketed_lgbm",
]:
    err = valid[model_name] - valid["target_v"]

    plt.figure(figsize=(10, 6))
    plt.hist(err, bins=80)

    plt.axvline(0, linestyle="--", linewidth=1)

    plt.xlabel("Prediction error, km/s")
    plt.ylabel("Count")
    plt.title(f"Error Distribution — {model_name}")
    plt.grid(True)
    plt.show()

# %%
for model_name in [
    "pred_blend",
    "pred_global_lgbm",
    "pred_bucketed_lgbm",
]:
    err = valid[model_name] - valid["target_v"]

    plt.figure(figsize=(14, 6))
    plt.scatter(
        valid["lead_hours"],
        err,
        alpha=0.15,
        s=8,
    )

    plt.axhline(0, linestyle="--", linewidth=1)

    plt.xlabel("Lead hour")
    plt.ylabel("Prediction error, km/s")
    plt.title(f"Residuals vs Lead Hour — {model_name}")
    plt.grid(True)
    plt.show()

# %%
def plot_forecast_curve(issue_time):
    issue_time = pd.Timestamp(issue_time, tz="UTC")

    g = valid[valid["issue_time"] == issue_time].sort_values("lead_hours")

    if g.empty:
        print(f"No rows for issue_time={issue_time}")
        return

    plt.figure(figsize=(14, 7))

    plt.plot(
        g["valid_time"],
        g["target_v"],
        label="Observed target",
        linewidth=3,
    )

    for model_name in [
        "pred_blend",
        "pred_global_lgbm",
        "pred_bucketed_lgbm",
    ]:
        plt.plot(
            g["valid_time"],
            g[model_name],
            label=model_name,
            linewidth=2,
        )

    plt.xlabel("Valid time")
    plt.ylabel("Solar wind speed, km/s")
    plt.title(f"96h Forecast Curve from issue_time={issue_time}")
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
event_issues = (
    valid
    .groupby("issue_time")["target_v"]
    .max()
    .sort_values(ascending=False)
    .head(10)
)

event_issues
# Out:
# issue_time
# 2023-11-08 08:00:00+00:00    735.0
# 2023-11-08 04:00:00+00:00    735.0
# 2023-11-08 10:00:00+00:00    735.0
# 2023-11-08 09:00:00+00:00    735.0
# 2023-11-08 06:00:00+00:00    735.0
# 2023-11-08 07:00:00+00:00    735.0
# 2023-11-08 05:00:00+00:00    735.0
# 2023-11-04 23:00:00+00:00    735.0
# 2023-11-05 10:00:00+00:00    735.0
# 2023-11-05 11:00:00+00:00    735.0
# Name: target_v, dtype: float64

# %%
plot_forecast_curve("2023-11-07 18:00:00+00:00")

# %%
bucket_summary_rows = []

for bucket, g_bucket in valid.groupby("lead_bucket"):
    y_true = g_bucket["target_v"].values

    for model_name in MODELS:
        y_pred = g_bucket[model_name].values

        bucket_summary_rows.append({
            "bucket": bucket,
            "model": model_name,
            "mae": mean_absolute_error(y_true, y_pred),
            "rmse": root_mean_squared_error(y_true, y_pred),
            "bias": float(np.mean(y_pred - y_true)),
            "n": len(g_bucket),
        })


bucket_summary = pd.DataFrame(bucket_summary_rows)
bucket_summary.sort_values(["bucket", "mae"])
# Out:
#             bucket               model         mae        rmse       bias  \
# 4   extended_49_96          pred_blend   84.144618  106.680479   1.251493
# 5   extended_49_96    pred_global_lgbm   86.606946  104.271315  31.756753
# 0   extended_49_96     pred_persist_1h   88.200142  112.526422  -1.839609
# 1   extended_49_96     pred_persist_6h   89.741833  114.390395  -1.986283
# 2   extended_49_96    pred_persist_24h   94.569738  120.363071  -2.302564
# 3   extended_49_96    pred_persist_27d  100.975055  127.502996   4.848719
# 6   extended_49_96  pred_bucketed_lgbm  106.292156  129.386532  64.367692
# 13    medium_25_48  pred_bucketed_lgbm   65.619816   81.935427   6.975159
# 11    medium_25_48          pred_blend   68.540464   88.806012  -1.740718
# 7     medium_25_48     pred_persist_1h   69.918343   91.947263  -2.442819
# 12    medium_25_48    pred_global_lgbm   72.965913   88.294352  23.645715
# 8     medium_25_48     pred_persist_6h   73.830373   96.338968  -2.709488
# 9     medium_25_48    pred_persist_24h   84.088722  107.669109  -3.137597
# 10    medium_25_48    pred_persist_27d   99.794922  124.042064   4.274936
# 14      short_1_24     pred_persist_1h   38.118549   56.253471  -0.661514
# 20      short_1_24  pred_bucketed_lgbm   39.018028   52.966196   5.221371
# 18      short_1_24          pred_blend   40.119878   57.665660  -0.909208
# 15      short_1_24     pred_persist_6h   46.813228   66.117887  -0.958504
# 19      short_1_24    pred_global_lgbm   54.443202   67.880722  22.992683
# 16      short_1_24    pred_persist_24h   68.739514   90.684812  -1.766843
# 17      short_1_24    pred_persist_27d   92.500146  118.201636   6.086792
#
#          n
# 4   300217
# 5   300217
# 0   300217
# 1   300217
# 2   300217
# 3   300217
# 6   300217
# 13  151450
# 11  151450
# 7   151450
# 12  151450
# 8   151450
# 9   151450
# 10  151450
# 14  154231
# 20  154231
# 18  154231
# 15  154231
# 19  154231
# 16  154231
# 17  154231

# %%
metrics_by_lead = pd.read_csv("../../reports/speed_quantile_metrics_by_lead.csv")

plt.figure(figsize=(14, 6))
plt.plot(metrics_by_lead["lead_hours"], metrics_by_lead["raw_coverage_80"], label="raw")
plt.plot(metrics_by_lead["lead_hours"], metrics_by_lead["cal_coverage_80"], label="calibrated")
plt.axhline(0.80, linestyle="--", label="target 80%")
plt.xlabel("Lead hour")
plt.ylabel("Coverage")
plt.title("Test 80% Interval Coverage by Lead Hour")
plt.grid(True)
plt.legend()
plt.show()

# %%
TARGET_COVERAGE = 0.80


pred = pd.read_csv("../../reports/speed_quantile_valid_predictions.csv")

pred["issue_time"] = pd.to_datetime(pred["issue_time"], utc=True)
pred["valid_time"] = pd.to_datetime(pred["valid_time"], utc=True)


def calibrate_by_lead(df: pd.DataFrame, target_coverage: float = 0.80) -> pd.DataFrame:
    rows = []

    for lead, g in df.groupby("lead_hours"):
        y = g["target_v"].to_numpy()
        q50 = g["pred_q50"].to_numpy()
        q10 = g["pred_q10"].to_numpy()
        q90 = g["pred_q90"].to_numpy()

        lower_width = np.maximum(q50 - q10, 1e-6)
        upper_width = np.maximum(q90 - q50, 1e-6)

        # Find how much we need to expand interval around q50
        # so that target_coverage fraction of observations are inside.
        required_scale = np.maximum(
            np.where(y < q50, (q50 - y) / lower_width, 0.0),
            np.where(y > q50, (y - q50) / upper_width, 0.0),
        )

        scale = np.quantile(required_scale, target_coverage)

        rows.append({
            "lead_hours": lead,
            "scale": max(1.0, float(scale)),
            "n": len(g),
        })

    return pd.DataFrame(rows)


calibration = calibrate_by_lead(pred, TARGET_COVERAGE)
calibration.head()
# Out:
#    lead_hours     scale     n
# 0           1  1.090068  6560
# 1           2  1.139533  6532
# 2           3  1.140200  6511
# 3           4  1.150246  6495
# 4           5  1.151235  6488

# %%
pred_cal = pred.merge(calibration, on="lead_hours", how="left")

pred_cal["cal_q10"] = (
    pred_cal["pred_q50"]
    - pred_cal["scale"] * (pred_cal["pred_q50"] - pred_cal["pred_q10"])
)

pred_cal["cal_q90"] = (
    pred_cal["pred_q50"]
    + pred_cal["scale"] * (pred_cal["pred_q90"] - pred_cal["pred_q50"])
)

pred_cal["cal_q50"] = pred_cal["pred_q50"]

# %%
def coverage(y, q10, q90):
    return np.mean((y >= q10) & (y <= q90))


raw_coverage = coverage(
    pred_cal["target_v"],
    pred_cal["pred_q10"],
    pred_cal["pred_q90"],
)

cal_coverage = coverage(
    pred_cal["target_v"],
    pred_cal["cal_q10"],
    pred_cal["cal_q90"],
)

raw_width = np.mean(pred_cal["pred_q90"] - pred_cal["pred_q10"])
cal_width = np.mean(pred_cal["cal_q90"] - pred_cal["cal_q10"])

print(f"Raw coverage:        {raw_coverage:.3f}")
print(f"Calibrated coverage: {cal_coverage:.3f}")
print(f"Raw width:           {raw_width:.1f} km/s")
print(f"Calibrated width:    {cal_width:.1f} km/s")
# Out:
# Raw coverage:        0.646
# Calibrated coverage: 0.800
# Raw width:           137.0 km/s
# Calibrated width:    184.6 km/s

# %%
rows = []

for lead, g in pred_cal.groupby("lead_hours"):
    rows.append({
        "lead_hours": lead,
        "raw_coverage": coverage(g["target_v"], g["pred_q10"], g["pred_q90"]),
        "cal_coverage": coverage(g["target_v"], g["cal_q10"], g["cal_q90"]),
        "raw_width": np.mean(g["pred_q90"] - g["pred_q10"]),
        "cal_width": np.mean(g["cal_q90"] - g["cal_q10"]),
        "scale": g["scale"].iloc[0],
        "n": len(g),
    })

lead_cal = pd.DataFrame(rows)

# %%
plt.figure(figsize=(14, 6))

plt.plot(lead_cal["lead_hours"], lead_cal["raw_coverage"], label="Raw coverage")
plt.plot(lead_cal["lead_hours"], lead_cal["cal_coverage"], label="Calibrated coverage")

plt.axhline(0.80, linestyle="--", linewidth=1, label="Target 80%")

plt.xlabel("Lead hour")
plt.ylabel("Coverage")
plt.title("80% Interval Coverage by Lead Hour")
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14, 6))

plt.plot(lead_cal["lead_hours"], lead_cal["raw_width"], label="Raw width")
plt.plot(lead_cal["lead_hours"], lead_cal["cal_width"], label="Calibrated width")

plt.xlabel("Lead hour")
plt.ylabel("Interval width, km/s")
plt.title("Prediction Interval Width by Lead Hour")
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14, 6))

plt.plot(lead_cal["lead_hours"], lead_cal["scale"])

plt.xlabel("Lead hour")
plt.ylabel("Interval expansion scale")
plt.title("Lead-Hour Calibration Scale")
plt.grid(True)
plt.show()

# %%
pred_cal.to_csv("../../reports/speed_quantile_valid_predictions_calibrated.csv", index=False)
calibration.to_csv("../../models/lead_hour_interval_calibration.csv", index=False)
